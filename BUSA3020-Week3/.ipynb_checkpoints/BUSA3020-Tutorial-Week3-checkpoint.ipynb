# %% [markdown]
# # Week 3 Tutorial {-}
#
#
# ### Unit Convenor & Lecturer {-}
# [George Milunovich](https://www.georgemilunovich.com)
# [george.milunovich@mq.edu.au](mailto:george.milunovich@mq.edu.au)
#
# ---
#
# **Objectives**
#
# - Q1: Go over any questions from Week 2 Tutorial that were left unfinished
# - Q2: Complete Kaggle's [Functions and Getting Help Tutorial](https://www.kaggle.com/colinmorris/functions-and-getting-help)
# - Q3: Work on Assignment 1
